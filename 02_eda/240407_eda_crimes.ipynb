# %% [markdown]
# # Análisis Exploratorio de Datos
# ---

# %%
import pandas as pd

# %%
crimes = pd.read_csv('/content/drive/MyDrive/Crimes_-_2001_to_Present_20240406.csv')

# %%
crimes.info(show_counts = True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8032948 entries, 0 to 8032947
# Data columns (total 22 columns):
#  #   Column                Non-Null Count    Dtype
# ---  ------                --------------    -----
#  0   ID                    8032948 non-null  int64
#  1   Case Number           8032948 non-null  object
#  2   Date                  8032948 non-null  object
#  3   Block                 8032948 non-null  object
#  4   IUCR                  8032948 non-null  object
#  5   Primary Type          8032948 non-null  object
#  6   Description           8032948 non-null  object
#  7   Location Description  8020119 non-null  object
#  8   Arrest                8032948 non-null  bool
#  9   Domestic              8032948 non-null  bool
#  10  Beat                  8032948 non-null  int64
#  11  District              8032901 non-null  float64
#  12  Ward                  7418095 non-null  float64
#  13  Community Area        7419471 non-null  float64
# ...

# %%
for elements in crimes.columns:
    print(crimes[elements].unique())
# Out:
# [11037294 11646293 11645836 ... 12118237 12142591 12002171]
# ['JA371270' 'JC213749' 'JC212333' ... 'JD311791' 'JD340297' 'JD177406']
# ['03/18/2015 12:00:00 PM' '12/20/2018 03:00:00 PM'
#  '05/01/2016 12:25:00 AM' ... '05/06/2020 09:51:00 AM'
#  '09/14/2020 06:13:00 PM' '07/27/2020 03:02:00 PM']
# ['0000X W WACKER DR' '023XX N LOCKWOOD AVE' '055XX S ROCKWELL ST' ...
#  '012XX W Montana St' '037XX S Union Ave' '014XX N Sandburg TER']
# ['1153' '1154' '2820' '0810' '0820' '0460' '051A' '0430' '0890' '1195'
#  '143A' '1130' '1120' '3730' '1563' '0486' '0420' '1140' '2825' '0860'
#  '0620' '2024' '0560' '2027' '2250' '2014' '0281' '0454' '141A' '0910'
#  '1310' '1320' '5000' '1150' '0498' '041A' '1220' '1206' '1156' '1210'
#  '5002' '1811' '4387' '0610' '1155' '2826' '1110' '1152' '0496' '1751'
#  '1122' '1752' '1780' '0520' '0265' '0440' '1121' '1754' '1477' '0930'
#  '1330' '1345' '0340' '1822' '0320' '0497' '031A' '0530' '0870' '502P'
# ...

# %%
crimes['Primary Type'].value_counts().plot.bar()
# Out:
# <Axes: xlabel='Primary Type'>

# %%
crimes['Location Description'].value_counts().head(10).plot.bar()
# Out:
# <Axes: xlabel='Location Description'>

# %%
crimes['Arrest'].value_counts().plot.bar()
# Out:
# <Axes: xlabel='Arrest'>

# %%
crimes['Ward'].plot.hist(alpha = 0.5)
# Out:
# <Axes: ylabel='Frequency'>

# %%
crimes['Domestic'].value_counts().plot.pie(autopct='%1.1f%%')
# Out:
# <Axes: ylabel='count'>

# %%
crimes['Arrest'].value_counts().plot.pie(autopct='%1.1f%%')
# Out:
# <Axes: ylabel='count'>

# %%
crimes['Year'].value_counts().sort_index().plot.line()
# Out:
# <Axes: xlabel='Year'>

# %% [markdown]
# La primera observación es que es necesario estandarizar el formato de las columnas a uno que permita trabahjar facilmente con ellas y que no contenga espacios.
#
# En este caso fue observable que las columnas
#
# *   Location Description
# *   District
# *   Ward
# *   Community Area
# *   X Coordinate
# *   Y Coordinate
# *   Latitude
# *   Longitude
# *   Location
#
# De igual forma es notable que el ID es la llave de identificación del crimen pero el Case Number es el número de identificación de caso policial relacionado que no necesariamente es único pues en un mismo caso se pudo llevar a cabo varios crímenes relacionados pero si será utilizado como llave de la relación con las víctimas.
#
# Por otro lado, si no se tienen en cuenta las variables que son códigos de identificación o variables de ubicación. solamente se tiene una variable cuantitativa que es Year.
